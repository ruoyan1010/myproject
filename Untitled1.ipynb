# %%
import torch
print("torch:", torch.__version__)
print("cuda_available:", torch.cuda.is_available())
print("executable:", __import__("sys").executable)
# Out:
# torch: 2.9.1+cpu
# cuda_available: False
# executable: /home/dyx/projects/myproject/env/bin/python3
